# %%
conda install -c anaconda requests
# Out:
# Note: you may need to restart the kernel to use updated packages.
# usage: _conda.exe [-h] [-V] command ...
# _conda.exe: error: argument command: invalid choice: 'C:\\Users\\andre\\anaconda3\\Scripts\\conda-script.py' (choose from 'clean', 'compare', 'config', 'create', 'help', 'info', 'init', 'install', 'list', 'package', 'remove', 'uninstall', 'run', 'search', 'update', 'upgrade')

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {   
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035    
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# springboard

# %%
comments
# Out:
#          id                     name  anonymous hostProgramName  \
# 0    276568  Guilherme golabek brein      False            None
# 1    276147          Charlotte Urvoy      False            None
# 2    275972                Anonymous       True            None
# 3    275872             Ahmad Khalaf      False            None
# 4    275855        Morgane Favchtein      False            None
# ..      ...                      ...        ...             ...
# 905  234894             Stephanie S.      False            None
# 906  234877                 Joe Fang      False            None
# 907  234838                    Zeina      False            None
# 908  242681                     Jean      False            None
# 909  234178                      Ben      False            None
#
#      graduatingYear  isAlumni                         jobTitle  \
# 0            2018.0     False                 Senior Associate
# 1            2021.0     False                   UX UI Designer
# ...

# %%
comments.drop(['hostProgramName', 'user', 'comments', 'createdAt', 'queryDate'], axis = 1, inplace = True)

# removed useless columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-f220bcde6e1e> in <module>
# ----> 1 comments.drop(['hostProgramName', 'user', 'comments', 'createdAt', 'queryDate'], axis = 1, inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
comments['body'] = comments['body'].str.replace('<span class="truncatable"><p></p><p>', '')
comments['body'] = comments['body'].str.replace('<span class="truncatable"><p>', '')
comments['body'] = comments['body'].str.replace('<p>', '')

# cleaned some strings

# %%
comments
# Out:
#          id                     name  anonymous  graduatingYear  isAlumni  \
# 0    276568  Guilherme golabek brein      False          2018.0     False
# 1    276147          Charlotte Urvoy      False          2021.0     False
# 2    275972                Anonymous       True          2021.0     False
# 3    275872             Ahmad Khalaf      False          2021.0     False
# 4    275855        Morgane Favchtein      False          2021.0     False
# ..      ...                      ...        ...             ...       ...
# 905  234894             Stephanie S.      False          2015.0      True
# 906  234877                 Joe Fang      False          2015.0      True
# 907  234838                    Zeina      False          2016.0      True
# 908  242681                     Jean      False          2016.0      True
# 909  234178                      Ben      False          2016.0      True
#
#                             jobTitle  \
# 0                   Senior Associate
# ...

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# <ipython-input-5-ada7bc74fd3a>:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# app-academy
# springboard

# %%
locations_list
# Out:
# [      id               description  country.id   country.name country.abbrev  \
#  0  15901           Berlin, Germany        57.0        Germany             DE
#  1  16022       Mexico City, Mexico        29.0         Mexico             MX
#  2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
#  3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
#  4  16109             Paris, France        38.0         France             FR
#  5  16375  Miami, FL, United States         1.0  United States             US
#  6  16376             Madrid, Spain        12.0          Spain             ES
#  7  16377          Barcelona, Spain        12.0          Spain             ES
#  8  16709          Lisbon, Portugal        28.0       Portugal             PT
#  9  17233                    Online         NaN            NaN            NaN
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
# ...

# %%
locations = pd.concat(locations_list)
locations
# Out:
#       id                       description  country.id   country.name  \
# 0  15901                   Berlin, Germany        57.0        Germany
# 1  16022               Mexico City, Mexico        29.0         Mexico
# 2  16086            Amsterdam, Netherlands        59.0    Netherlands
# 3  16088                 Sao Paulo, Brazil        42.0         Brazil
# 4  16109                     Paris, France        38.0         France
# 5  16375          Miami, FL, United States         1.0  United States
# 6  16376                     Madrid, Spain        12.0          Spain
# 7  16377                  Barcelona, Spain        12.0          Spain
# 8  16709                  Lisbon, Portugal        28.0       Portugal
# 9  17233                            Online         NaN            NaN
# 0  15704  San Francisco, CA, United States         1.0  United States
# 1  15705  New York City, NY, United States         1.0  United States
# ...

# %%
locations.rename(columns= {'country.id': 'country_id', 'country.name': 'country_name', 'country.abbrev': 'country_abbrev', 'city.id': 'city_id', 'city.name' : 'city_name', 'city.keyword': 'city_keyword'}, inplace = True)

# renamed columns with 'dots' with '_' to make it easier to call in mysql

# %%
locations.drop(['state.id', 'state.name', 'state.abbrev', 'state.keyword'], axis =1, inplace = True)

# removed useless columns

# %%
locations['country_name'].fillna('Online', inplace = True)
locations['country_id'].fillna('Online', inplace = True)
locations['country_abbrev'].fillna('Online', inplace = True)
locations['city_id'].fillna('Online', inplace = True)
locations['city_name'].fillna('Online', inplace = True)
locations['city_keyword'].fillna('Online', inplace = True)

# renamed all null values with Online

# %%
locations
# Out:
#       id                       description country_id   country_name  \
# 0  15901                   Berlin, Germany         57        Germany
# 1  16022               Mexico City, Mexico         29         Mexico
# 2  16086            Amsterdam, Netherlands         59    Netherlands
# 3  16088                 Sao Paulo, Brazil         42         Brazil
# 4  16109                     Paris, France         38         France
# 5  16375          Miami, FL, United States          1  United States
# 6  16376                     Madrid, Spain         12          Spain
# 7  16377                  Barcelona, Spain         12          Spain
# 8  16709                  Lisbon, Portugal         28       Portugal
# 9  17233                            Online     Online         Online
# 0  15704  San Francisco, CA, United States          1  United States
# 1  15705  New York City, NY, United States          1  United States
# 2  15862                            Online     Online         Online
# ...

# %%
courses = pd.concat(courses_list)
courses.head(10)
# Out:
#                               courses       school  school_id
# 0             Cyber Security Bootcamp     ironhack      10828
# 1             Data Analytics Bootcamp     ironhack      10828
# 2            Data Analytics Part-Time     ironhack      10828
# 3               UX/UI Design Bootcamp     ironhack      10828
# 4              UX/UI Design Part-Time     ironhack      10828
# 5            Web Development Bootcamp     ironhack      10828
# 6           Web Development Part-Time     ironhack      10828
# 0                       Bootcamp Prep  app-academy      10525
# 1  Software Engineer Track: In-Person  app-academy      10525
# 2                    App Academy Open  app-academy      10525

# %%
badges = pd.concat(badges_list)


badges['description'] = badges['description'].str.replace('<p>', '')

badges['description'] = badges['description'].str.replace('</p>', '')

badges
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0                 School offers fully online courses     ironhack      10828
# 1  School publishes a third-party verified outcom...     ironhack      10828
# 2        School offers part-time and evening classes     ironhack      10828
# 0                 School offers fully online courses  app-academy      10525
# 1        School offers part-time and evening classes  app-academy      10525
# 2                    School guarantees job placement  app-academy      10525
# ...

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)


schools['description'] = schools['description'].str.replace('<span class="truncatable"><p>', '')
schools['description'] = schools['description'].str.replace('<span class="read-more-text">', '')
schools['description'] = schools['description'].str.replace('<a class="read-more-button">', '')
schools['description'] = schools['description'].str.replace('</span></p><p>', '')
schools['description'] = schools['description'].str.replace('</p><p>', '')

# # cleaned some strings


schools
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
#
#                                          description  \
# 0  Ironhack is a global tech school with 9 campus...
# 0  App Academy is a coding school that offers onl...
# 0  Springboard is an online learning platform tha...
#
#                                              LogoUrl       school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     ironhack      10828
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  app-academy      10525
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  springboard      11035

# %%
pip install mysql-connector-python

# %%
pip install PyMySQL

# %%
import mysql.connector

# %%
import pymysql

# %%
cnx = mysql.connector.connect(user = 'root', password = 'Emilio87!', host = 'localhost')

# %%
cnx.is_connected()
# Out:
# True

# %%
cursor = cnx.cursor()

# %%
query = ("""CREATE DATABASE Project;""")  #### creating a new database in sql

cursor.execute(query)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="Emilio87!",
                               db="Project"))

# %%
comments.to_sql('comments', con = engine, if_exists = 'append', chunksize = 1000)

# %%
locations.to_sql('locations', con = engine, if_exists = 'append', chunksize = 1000)

# %%
courses.to_sql('courses', con = engine, if_exists = 'append', chunksize = 1000)

# %%
badges.to_sql('badges', con = engine, if_exists = 'append', chunksize = 1000)

# %%
schools.to_sql('schools', con = engine, if_exists = 'append', chunksize = 1000)

# %%
cnx.commit()

# %%
cursor.close()
cnx.close()

# %%
cnx.is_connected()
# Out:
# False
